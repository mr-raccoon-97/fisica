# %% [markdown]
# #### Problema 1.
#
# Antes del descubrimiento del neutrón, muchos pensaban que el núcleo estaba formado por protones y electrones, y que el número atómico era igual al exceso de protones. La desintegración beta parecía confirmar esta idea: después de todo, los electrones salen disparados, ¿no implica esto que había electrones en el interior?
#
# Utilice la relación de incertidumbre posición-momento:
#
# $$\Delta x \Delta p \geq \frac{\hbar}{2}$$
#
# Para estimar el momento mínimo de un electrón confinado en un núcleo (radio $10^{-11}$ cm). A partir de la relación relativista energía-momento:
#
# $$E^2 - p^2c^2 = m^2c^4$$
#
# Determine la energía correspondiente y compárela con la de un electrón emitido en, digamos, la desintegración beta del tritio:
#
# ![image-1.png](attachment:image-1.png)
#
# Este resultado convenció a algunos de que el electrón del decaimiento beta no podía estar dando vueltas dentro del núcleo, sino que debía producirse en la propia desintegración.

# %% [markdown]
# ### Solución
#
# La relación de incertidumbre nos dice que:
#
# $$\Delta x \Delta p \geq \frac{\hbar}{2}$$
#
# La incertidumbre asociada a la posición viene del radio del nucleo, del orden de $1 \text{fm}$, por lo que:
#
# $$ \Delta p = \frac{\hbar}{2 \Delta x} = \frac{\hbar}{2 \times 10^{-15} \text{m}} = 5.274 \times 10^{-20}$$
#
# Usando la relación relativista de la energía-momento, la energía asociada a este electrón sera:
#
# $$ E = c \sqrt{(p_{min}^2 + m^2c^2)} \approx 98.663 \text{MeV}$$
#
# La energia maxima con la que puede salir despedido un electron proveniente de la desintegración beta del Tritio es de $18.6 \text{keV}$, lo que indica que el electrón no puede estar confinado en el núcleo, ya que es tres ordenes de magnitud menor.

# %% [markdown]
# ### Problema 2
#
# La diferencia de masas entre los decupletes muestra que es igual entre las filas:
# $$m_{\Delta} - m_{\Sigma^*} = m_{\Sigma^*} - m_{\Xi^*} = m_{\Xi^*} - m_{\Omega}$$
#
# Utiliza esta fórmula (como hizo Gell-Mann) para predecir la masa del $\Omega^-$, utilizando la media de los dos primeros espaciamientos para estimar el tercero. ¿Cuál es la diferencia entre tu predicción y el valor observado?

# %% [markdown]
# ### Solución

# %% [markdown]
# Usemos la tabla de masas de los bariones para hallar la masa del $\Omega^-$:

# %% [markdown]
# ![image-13.png](attachment:image-13.png)

# %% [markdown]
# $$ m_{\Delta} - m_{\Sigma^*} = 1232 - 1385 = -153$$
#
# $$ m_{\Sigma^*} - m_{\Xi^*} = 1385 - 1532 = -147$$
#
# Por lo que se puede estimar la diferencia de masas entre el barión $\Xi$ y el barión $\Omega^-$ como un promedio de las diferencias de masas:
#
# $$ m_{\Xi} - m_{\Omega} = \frac{-153-147}{2} = -150$$
#
# Si se tiene en cuenta que la masa del barion $\Xi$ es de $1533$, la masa del barion $\Omega^-$ sera de $1533 + 150 = 1683$,
# lo que contrasta con el valor observado de $1672$ en tan solo $11$ unidades.

# %% [markdown]
# ### Problema 3
#
# Los miembros del decuplete de bariones suelen desintegrarse al cabo de $10^{-23}$ segundos en un barión más ligero (del octeto de bariones) y un mesón (del octeto de mesones pseudoescalares). Así, por ejemplo, $\Delta^{++} \rightarrow p^+ + \pi^+$.
#
# Decuplete de bariones:
#
# ![image-14.png](attachment:image-14.png)
#
# Octeto de bariones:
#
# ![image-5.png](attachment:image-5.png)
#
# Octeto de mesones:
#
# ![image-4.png](attachment:image-4.png)
#
#
#
# - Enumere todos los modos de desintegración de este de para el $\Delta^-$, $\Sigma^{*+}$ y $\Xi^{*-}$. Recuerde que estas desintegraciones deben conservar la carga y la extrañeza (son interacciones fuertes).
#
# - En cada desintegración debe haber suficiente masa en la partícula original para cubrir las masas de los productos de la desintegración. (Puede haber más que suficiente; la sobrante se ’absorberá’ en forma de energía cinética en el estado final). Comprueba cada uno de las desintegraciones que propusiste en la parte (a) para ver cuáles cumplen este criterio. Los demás están cinemáticamente prohibidos.

# %% [markdown]
# ### Solución
#
# Veamos la carga y la extrañeza de las partículas del decuplete:
#
# - $\Delta^-$: $Q = -1$, $S = 0$
# - $\Sigma^{*+}$: $Q = 1$, $S = -1$
# - $\Xi^{*-}$: $Q = -1$, $S = -2$
#
# Estas deben desintegrarse en un barión y un mesón del octeto de bariones y mesones. Veamos las posibles cargas y extrañezas de los productos de la desintegración:
#
# Para la particula $\Delta^-$ las posibles desintegraciones son:
#
# - $\Delta^- \rightarrow n + \pi^-$
# - $\Delta^- \rightarrow \Sigma^- + K^0$
#
# Para la particula $\Sigma^{*+}$
#
# Bariones del octete:
