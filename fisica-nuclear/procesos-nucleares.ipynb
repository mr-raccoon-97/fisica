# %% [markdown]
# ## Procesos nucleares
#
# La estructura de un núcleo está definida por los estados del sistema cuántico nuclear. El núcleo revela su estructura mediante una variedad de procesos interactivos en los cuales las transformaciones de los estados cuánticos ocurren como un fenómeno observable.
#
# Uno de estos procesos es la emisión de radiación $\gamma$, que ocurre cuando un núcleo en un estado excitado decae a un estado de menor energía. La radiación $\gamma$ es una onda electromagnética de alta frecuencia y corta longitud de onda.
#
# La radiación también puede tomar forma de fragmentos o partículas eyectadas. Estos fenómenos son llamados desintegraciones $\alpha$ y $\beta$. Los procesos $\alpha$, $\beta$ y $\gamma$ representan las tres variedades específicas de radiactividad. Cada emisión está asociada a cierto tipo de inestabilidad nuclear, y cada una es acompañada por una transición de energía en el núcleo.
#
# La radiactividad implica la desintegración espontánea de un núcleo atómico inestable.

# %% [markdown]
# Hemos interpretado la radiactividad como la desintegración de un núcleo inestable. Describimos esto ahora en el lenguaje de la física cuántica y trataremos los fenómenos en términos de transiciones entre estados nucleares.
#
# Los decaimientos $\alpha$ y $\beta$ traen cambios definidos en las especies nucleares; sin embargo, la radiación $\gamma$ solo causa un cambio en los estados de un determinado núcleo.

# %% [markdown]
# ![image-15.png](attachment:image-15.png)

# %% [markdown]
# En la figura se observa el esquema de decaimiento de $^{80}Br$. Los niveles de energía de los núcleos están conectados por transiciones $\beta$ y $\gamma$. La cantidad de energía liberada en cada transición, en $\text{MeV}$, está indicada en la figura. Los procesos $\beta^+$ y $\beta^-$ son distintos.

# %% [markdown]
# La carga y el número total de nucleones debe conservarse en cada desintegración. Conocemos que una partícula $\alpha$ es un núcleo de $^4He$, y podemos expresar la desintegración $\alpha$ como:
#
# $$ _Z^A X \rightarrow _{Z-2}^{A-4}Y + _2^4He $$
#
# Para las desintegraciónes $\beta^-$ y $\beta^+$, un electrón y un positrón son emitidos, respectivamente. La desintegración $\beta^-$ se expresa como:
#
# $$ _Z^A X \rightarrow _{Z+1}^{A}Y + e^- + \bar{\nu} $$
#
# $$ _Z^A X \rightarrow _{Z-1}^{A}Y + e^+ + \nu $$
#
# Donde $\bar{\nu}$ y $\nu$ se denominan antineutrinos y neutrinos, respectivamente y son partículas neutras con spin $1/2$. Cada una de estas transformaciones procede de un núcleo base $X$ a un núcleo derivado $Y$, y las tres transiciones pueden ser descritas como:
#
# $$ (Z, N) \rightarrow (Z-2, N-2) \quad \text{para desintegración} \quad \alpha $$
# $$ (Z, N) \rightarrow (Z+1, N-1) \quad \text{para desintegración} \quad \beta^- $$
# $$ (Z, N) \rightarrow (Z-1, N+1) \quad \text{para desintegración} \quad \beta^+ $$

# %% [markdown]
# Las propiedades de desintegración incluidas en las fuentes de datos son para cada núcleo:
#
# - La vida media
# - El modo de desintegración
# - La energía liberada en la desintegración
#
# Estas propiedades proveen una huella observable para cada radionucleido.

# %% [markdown]
# ### Ley de desintegración exponencial
#
# La inestabilidad es una propiedad de las especies y la vida media es una medida del tiempo de vida de un núcleo. Sin embargo la vida media, no determina el tiempo exacto de desintegración de un núcleo inestable, ya que la desintegración ocurre como un evento discreto y aleatorio. Tal acto de azar es predecible solo en términos de una probabilidad de ocurrencia de una determinada transición en un intervalo de tiempo dado.
#
# Sean $\gamma$ la cantidad fundamental que describe la probabilidad por unidad de tiempo de la desintegración $X \rightarrow Y + r$, donde $r$ denota la radiación emitida.
#
# Se puede determinar $\gamma$ experimentalmente si se observa la radiación de una fuente conteniendo varios núcleos de especies $X$. Procedemos definiendo $N(t)$ como el número de núcleos de la especie $X$ de la muestro en el tiempo $t$.
#
# Consideramos un pequeño cambio $dN$ en un intervalo de tiempo $dt$ e identificamos la cantidad positiva $-dN$, como el número de desintegraciones en dicho intervalo. La cantidad $dN/N$ representa la probabilidad de desintegración en en terminos del numero de desintegraciónes en el tiempo $t$, por lo que podemos escribir:
#
# $$ -\frac{dN}{N} = \gamma dt $$
#
# A la probabilidad de desintegración en el intervalo $t$ y $t + dt$. Esto resulta en la "actividad", o tasa de desintegración, proporcional al número de núcleos presentes. La actividad se define como:
#
# $$ -\frac{dN}{dt} = \gamma N $$
#
# Y podemos obtener la cantidad de núcleos en el tiempo $t$ como:
#
# $$ N(t) = N_0 e^{-\gamma t} $$
#
# Esta cantidad es la ley de desintegración exponencial, donde $N_0$ es el número de núcleos en el tiempo $t = 0$. Un núcleo en una muestra, realizara una transición $X \rightarrow Y$, desde un tiempo $t = 0$ en adelante, con una probabilidad $\gamma$ por unidad de tiempo. Obtenemos entonces el tiempo de vida promedio $\langle t \rangle$ como:
#
# $$ \langle t \rangle = \frac{\int_0^{\infty} t \gamma e^{-\gamma t} dt}{\int_0^{\infty} \gamma e^{-\gamma t} dt} = \frac{1}{\gamma} \equiv \tau$$
#
# $$\Rightarrow N(t) = N_0 e^{-t/\tau}$$

# %% [markdown]
# ![image-16.png](attachment:image-16.png)

# %% [markdown]
# La vida media $\tau_{1/2}$ ya fue definido como el tiempo requerido para que la cantidad de núcleos se reduzca a la mitad de su valor inicial.
#
# $$N(\tau_{1/2}) = N_0 e^{-\tau_{1/2}/\tau} = \frac{N_0}{2}$$
#
# $$\Rightarrow \tau_{1/2} = \tau \ln 2$$

# %% [markdown]
# Los resultados para $\tau$ y $\tau_{1/2}$ son interesantes por que conectan cantidades experimentales y teoricas, la vida de una muestra de un nucleo por una parte y por otro lado, la tasa de desintegración para un solo núcleo.

# %% [markdown]
# Podemos medur la actividad de una fuente contando la tasa de particulas cargadas emitidas usando un detector. Cada particula observada, representa una sola desintegración nuclear. Un contador tipico, esta compuesto por una camara de gas al cual se le aplica un campo electrico. La particula es contada, cuando los atomos del gas en la camar son ionizados por el paso de la particula y sus iones son colectados por el campo aplicado.
#
# La tasa de particulas contadas debe ser igual a la tasa de desintegración de la muestra $-dN/dt$, dejando de lado la eficiencia del detector. La eficiencia del detector depende de dos factores, la fracción total de angulo solido subtendido por el detector  y la probabilidad de una particula de producir una señal en el circuito. La constante de desintegración puede ser determinada facilmente por dicho experimento, usamos el hecho de que la cantidad medida depende del tiempo:
#
# $$-\frac{dN}{dt} = \gamma N= \gamma N_0 e^{-\gamma t} = \left(-\frac{dN}{dt}\right)_0 e^{-\gamma t}$$
#
# $$ \Rightarrow \log \left( - \frac{dN}{dt} \right) = \log \left( - \frac{dN}{dt} \right)_0 - \gamma t  $$

# %% [markdown]
# ### Reacciones en cadena
#
# Muchos radionucleidos muestran su actividad en cadena de desintegraciones secuenciales. Formulemos las ecuaciones que describen la desintegración de los núcleos en términos de una cascada de dos pasos.
#
# Sea la desintegración en dos pasos $X_1 \rightarrow X_2 + r$ y $X_2 \rightarrow X_3$. Cada transición tiene su probabilidad en unidades de tiempo, como en la siguiente figura:

# %% [markdown]
# ![image-17.png](attachment:image-17.png)

# %% [markdown]
# Tenemos entonces que:
#
# $$\frac{dN_1}{dt} = -\gamma_{12} N_1$$
# $$\frac{dN_2}{dt} = \gamma_{12} N_1 - \gamma_{23}N_2$$
# $$\frac{dN_3}{dt} = \gamma_{23} N_3$$
#
# Notamos que las cantidades se conservan y:
#
# $$N_1 + N_2 + N_3 = N_0$$
#
# $$\Rightarrow \frac{dN_1}{dt} + \frac{dN_2}{dt} + \frac{dN_3}{dt} = 0$$
#
# Resolviendo el sistema de ecuaciónes se obtienen las siguientes curvas:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Desintegraciones alfa
#
# La radiación de partículas alfa dio evidencia de la inestabilidad del núcleo. La emisión de este tipo de partículas está asociada con núcleos pesados inestables y es raramente vista en elementos con números atómicos $Z < 82$.
#
# El fragmento $\alpha$ emitido y su residuo, están unidos por una fuerza nuclear atractiva de corto alcance, y son repelidos por una interacción culombiana repulsiva.
#
# La energía de la radiación nuclear se absorbe fácilmente en la materia cuando la radiación está en forma de partículas alfa. Las cargas en movimiento pierden su energía cinética en colisiones ionizantes con los átomos en el medio material. Argumentos cinemáticos familiares nos dicen que estas pérdidas de energía por colisión son mayores para las partículas alfa que para la radiación beta, mucho más ligera. Se define un rango en el medio como la distancia en la que la partícula pierde toda su energía cinética. Un absorbente efectivo para partículas alfa podría ser una lámina de aluminio, una hoja de papel o incluso un volumen de aire. El rango disminuye con la densidad del medio absorbente y aumenta con la energía de la partícula.
#
# Además de la emisión de partículas alfa, los núcleos pesados pueden experimentar otro tipo de desintegración llamado fisión espontánea. En este proceso, el núcleo se divide en dos fragmentos de tamaño similar.

# %% [markdown]
# Las velocidades de las partículas $\alpha$ pueden ser medidas con precisión observando las deflexiones de estas en un campo magnético conocido. Un instrumento utilizado para este propósito es el espectrómetro de masas. La curva rango-energía resultante provee una determinación de la energía de la partícula $\alpha$.
#
# ![image-19.png](attachment:image-19.png)

# %% [markdown]
# EL típico proceso de desintegración $\alpha$ es:
#
# $$ X \rightarrow Y + \alpha $$
#
# Este es iniciado en estado fundamental del padre $X$ $\alpha$-activo. Es tambien posible para un nucleo, bajo ciertas condiciones emitir desde un estado exitado $X^*$ a un estado hijo $Y$. Las particulas emitidas en este caso tienen una energia cinetica mayor que en el caso de la desintegración del estado fundamental y se caracterizan por un rango mayor. Este tipo de desintegración es rara debido a que tiene que competir con la desintegración $\gamma$ dada por $X^* \rightarrow X + \gamma$.
#
# Experimentalmente se observa una relación inversa la vida media y la energía de las particulas $\alpha$.
#
# Si se aplica la conservación del momento y energía al proceso:
#
# $$ ^A_Z X \rightarrow ^{A-4}_{Z-2}Y + ^4_2He $$
#
# Notamos que esta desintegración produce una particula $\text{alpha}$ en un estado final con dos cuerpos, donde el nucleo padre, se toma como en reposo.
#
# ![image-36.png](attachment:image-36.png)

# %% [markdown]
# La conservación del la energpia relativista total provee la relación:
#
# $$ M_X c^2 = M_Y c^2 + K_Y + M_{\alpha} c^2 + K_{\alpha} $$
#
# Podemos añadir $Z$ masas de electrones a ambos lados, y expresar la expresion en terminos de masas atomicas:
#
# $$ M(^AX) c^2 = [M(^{A-4}Y) + M(^4\text{E})] c^2 + K_Y + K_{\alpha}$$
#
# El criterio para la inestabilidad $\alpha$ emerge de estas relaciones. El nucleo $X$ es $\alpha$ inestable, por lo que la desintegración $X \rightarrow Y + \alpha$ puede ocurrir cuando la masa $X$ excede la suma de las masas de $Y$ y $\alpha$.
#
# Definimos la energía de la desintegración $\alpha$ o $Q$-valor como:
#
# $$ Q = [M(^AX) - M(^{A-4}Y) - M(^4\text{He})] c^2 $$
#
# Este valor representa el total de la energpia liberada por las particulas finales:
#
# $$ Q = K_{\alpha} + K_Y $$
#
# Podemos usar la fórmula no relativista y escribir:
#
# $$Q = \frac{p^2}{2M_{\alpha}} + \frac{p^2}{2M_Y}$$
#
# $$ = \frac{p^2}{2M_{\alpha}}\left(1 + \frac{M_{\alpha}}{M_Y} \right) = K_{\alpha} \left( 1 + \frac{M_{\alpha}}{M_Y} \right)

# %% [markdown]
# La solución para $K_{\alpha}$ es una predicción unica para la energía cinetica de la particula $\alpha$.
#
# Ecuaciones relativistas son requeridas para la energía total, debido a que las energías en reposo cambian con la identidad de las partículas, mientras que las ecuaciones no relativistas son suficientes para la energía, ya que estas son mucho más pequeñas que las energías en reposo.

# %% [markdown]
# Otra ley de conservación que entra en juego en la determinación del estado final es la conservación del momento angular. Consideramos los espines $\vec{I}_X$ y $\vec{I}_Y$ con el momento angular $\vec{L}$ para el sistema $Y_{\alpha}$. Esto nos da restricciones para los números cuánticos.

# %% [markdown]
# #### Vida media y la desintegración $\alpha$
#
# Hay una gran variación de la vida media de un nucleido a otro, mientras que las energías $\alpha$ solo varían dentro de un orden de magnitud. Es aparente que $\tau_{1/2}$ debe tener una dependencia sensible en $Q$. Para explicar esto consideremos el siguiente potencial:
#
# ![image-37.png](attachment:image-37.png)

# %% [markdown]
# Este potencial describe como las partículas $\alpha$ interactúan con el núcleo. Los cuerpos se atraen entre si para distancias cortas, pero se repelen para distancias mayores debido al potencial de Coulomb. Esto genera una barrera de potencial que la partícula $\alpha$ debe superar para escapar del núcleo. Una partícula $\alpha$ puede escapar de esta barrera de potencial gracias al efecto de túnel cuántico. En este modelo, la función de onda estacionaria, en el nivel de energía $Q$, determina la probabilidad de $Y_{\alpha}$ de transpasar la barrera. Para una barrera rectangular en una dimensión, la probabilidad la partícula para transmitirse a través de la barrera es:
#
# $$ \exp(-\frac{2a}{\hbar} \sqrt{2\mu(V_0 - Q)}) $$

# %% [markdown]
# ### Desintegraciones beta
#
# La radiación de una fuente $\beta$ contiene partículas cargadas no nucleares caracterizadas por su masa pequeña y su poder de penetración en la materia. Los dos tipos de radiación beta incluyen las transiciones nucleares:
#
# $$ _Z^A X \rightarrow _{Z+1}^{A}Y + \beta^- $$
#
# $$ _Z^A X \rightarrow _{Z-1}^{A}Y + \beta^+ $$
#
# En las cuales el número de protones y neutrones cambia en uno, mientras que el número de masa queda constante.
#
# La transformación $\beta^-$ cambia un neutrón por un protón en el nucleo, mientras que la transformación $\beta^+$ cambia un protón por un neutrón. Las desintegraciones $\beta^-$ suelen ocurrir en núcleos con exceso de neutrones, mientras que las desintegraciones $\beta^+$ ocurren en núcleos con exceso de protones.

# %% [markdown]
# Se puede definir utilizando la fórmula semiempírica de la masa, un valle de estabilidad de nucleidos como en la siguiente figura. Los isobaros más estables corresponden a aquellos con menor masa.

# %% [markdown]
# ![image-38.png](attachment:image-38.png)

# %% [markdown]
# Las leyes de conservación del momento angular y la energía introducen otra forma de interpretar la desintegración $\beta$. Analicemos ahora los espines de las partículas que participan en el proceso.
#
# Una partícula cargada se emite con un espín $1/2$ en el caso del electrón en la desintegración $\beta^-$ o espín $1/2$ en el caso del positrón en la desintegración $\beta^+$. Como el número $A$ es constante, el espín del núcleo debe ser conservado. Esto generaría un desbalance en el espín de la desintegración si solo un electrón o un positrón fuese emitido.
#
# Por otra parte, a diferencia de la radiación $\alpha$, las particula $\beta$ no son bioenergéticas, estas se distribuyen en un espectro continuo de energia.
#
# ![image-39.png](attachment:image-39.png)

# %% [markdown]
# Esto revela que menos de la mitad del total de la energía liberada es acarreada por partículas cargadas. Con esto se puede concluir que existe otra partícula que se emite en la desintegración $\beta$. Esta partícula es el neutrino, que es una partícula neutra con espín $1/2$. La desintegración $\beta$ se puede escribir como:
#
# $$ _Z^A X \rightarrow _{Z+1}^{A}Y + e^- + \bar{\nu} $$
#
# $$ _Z^A X \rightarrow _{Z-1}^{A}Y + e^+ + \nu $$
#
# La conservación de la carga implica que el neutrino debe ser una partícula neutra. El problema del espín se resuelve si se asume que el neutrino tiene espín $1/2$.
#
# Los neutrinos se observaron por primera vez bajo el proceso de absorción:
#
# $$ \bar{\nu} + p \rightarrow n + e^+ $$

# %% [markdown]
# Aplicando las leyes de conservación cinemática a la desintegración $\beta^{-}$, esta se puede escribir como:
#
# $$ M_X c^2 = M_Y c^2 + K_Y + m_e c^2 + K_e + E_{\nu} $$
#
# Añadiendo $Z$ masas electrónicas en ambos miembros:
#
# $$ (M_X + Z m_e) c^2 = [M_Y + (Z+1) m_e] c^2 + K_Y + K_e + E_{\nu} $$
#
# $$ M(^A_ZX) c^2 = M(^A_{Z+1}) c^2 + K_Y + K_e + E_{\nu} $$
#
# Luego la energía de desintegración será:
#
# $$ Q = [M(^A_ZX) - M(^A_{Z+1}Y)] c^2 = K_Y + K_e + E_{\nu}$$

# %% [markdown]
# Analogamente, para la desintegración $\beta^+$:
#
# $$ M_X c^2 = M_Y c^2 + K_Y + m_e c^2 + K_e + E_{\nu} $$
#
# $$ (M_X + Z m_e) c^2 = [M_Y + (Z-1) m_e] c^2 + 2m_e c^2 + K_Y + K_e + E_{\nu} $$
#
# $$ M(^A_ZX) c^2 = M(^A_{Z-1}) c^2 + 2m_e c^2 + K_Y + K_e + E_{\nu} $$
#
# Luego la energía de desintegración será:
#
# $$ Q = [M(^A_ZX) - M(^A_{Z-1}Y) - 2m_e] c^2 = K_Y + K_e + E_{\nu}$$

# %% [markdown]
# Observemos la figura del espectro de energía de la desintegración $\beta$. La región del máximo $K_e$ y minimo $E_{\nu}$ es sensible a la energía del neutrino, ya que la probabilidad de desintegración es una función del momento del neutrino:
#
# $$ p_{\nu} = \sqrt{E_{\nu}^2 - m_{\nu}^2 c^4} / c$$
#
# El hecho de que $E_{\nu}$ y $m_{\nu} c^2$ aparezcan juntos en esta expresión implica que una masa $m_{\nu}$ es concebible si se pueden detectar eventos para valores suficientemente pequeños de $E_{\nu}$.

# %% [markdown]
# Un núcleo puede tambien sufrir un proceso de captura:
#
# $$ e^- + ^A_ZX \rightarrow ^A_{Z-1}Y + \nu $$
#
# Para el cual el electron es absorbido por el orbital atomico para iniciar la reacción nuclear. Un electrón capturado es detectado cuando rayos X son observados. Los rayos X resultan de la transición del electron externo para llenar el hueco dejado por el electrón capturado. Este proceso se balancea como:
#
# $$ M(^A_ZX) c^2 = M(^A_{Z-1}Y) c^2 + K_Y + E_{\nu} $$

# %% [markdown]
# Una desintegración $\beta$ presume que ambos $X$ e $Y$ estén en sus estados fundamentales. Una transición $\beta$ a veces deja un producto en un estado excitado $Y^*$, que puede decaer por emisión de radiación $\gamma$ como $Y^* \rightarrow Y + \gamma$. El valor de $Q$ en este caso determinal total de energía liberada incluyendo la energía de la radiación $\gamma$.
